# %% [markdown]
# # Virat Kohli Run Prediction

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Here we will predict the Runs Scored by the Virat Kohli or any other Batsman when we are given the number of 4's, 6's, bf, etc.. are given

# %% [markdown]
# #### by:- Gautam Mahto

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## import datasets

# %%
df=pd.read_csv('Dataset\\Virat_ODI.csv')

# %% [markdown]
# ### check the shape and look the data

# %%
df.head()
# Out:
#   runs  NotOut mins  bf fours sixes     sr Inns        Opp         Ground  \
# 0   12       0   33  22     1     0  54.54    1  Sri Lanka       Dambulla
# 1   37       0   82  67     6     0  55.22    2  Sri Lanka       Dambulla
# 2   25       0   40  38     4     0  65.78    1  Sri Lanka  Colombo (RPS)
# 3   54       0   87  66     7     0  81.81    1  Sri Lanka  Colombo (RPS)
# 4   31       0   45  46     3     1  67.39    2  Sri Lanka  Colombo (RPS)
#
#           Date
# 0  18 Aug 2008
# 1  20 Aug 2008
# 2  24 Aug 2008
# 3  27 Aug 2008
# 4  29 Aug 2008

# %%
df.shape
# Out:
# (248, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    248 non-null    object
#  1   NotOut  248 non-null    int64
#  2   mins    248 non-null    object
#  3   bf      248 non-null    object
#  4   fours   248 non-null    object
#  5   sixes   248 non-null    object
#  6   sr      248 non-null    object
#  7   Inns    248 non-null    object
#  8   Opp     248 non-null    object
#  9   Ground  248 non-null    object
#  10  Date    248 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 21.4+ KB

# %% [markdown]
# ### Check whether null values is present or not

# %%
df.isnull().sum()
# Out:
# runs      0
# NotOut    0
# mins      0
# bf        0
# fours     0
# sixes     0
# sr        0
# Inns      0
# Opp       0
# Ground    0
# Date      0
# dtype: int64

# %% [markdown]
# ### check whether duplicate item is present or not

# %%
df.duplicated().sum()
# Out:
# 0

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#      runs  NotOut mins   bf fours sixes      sr Inns           Opp  \
# 0      12       0   33   22     1     0   54.54    1     Sri Lanka
# 1      37       0   82   67     6     0   55.22    2     Sri Lanka
# 2      25       0   40   38     4     0   65.78    1     Sri Lanka
# 3      54       0   87   66     7     0   81.81    1     Sri Lanka
# 4      31       0   45   46     3     1   67.39    2     Sri Lanka
# 5       2       1    6    2     0     0  100.00    1     Sri Lanka
# 6      16       0   28   24     1     0   66.66    2      Pakistan
# 7    TDNB       0    -    -     -     -       -    -     Australia
# 8      79       1  121  104     9     2   75.96    2   West Indies
# 9      30       0   53   41     3     0   73.17    2     Australia
# 10     10       0   32   16     1     0   62.50    2     Australia
# 11     27       0   20   19     4     0  142.10    1     Sri Lanka
# 12     54       0   93   65     7     0   83.07    1     Sri Lanka
# ...

# %% [markdown]
# ### remove the dirty data

# %% [markdown]
# here there are few columns where player did not bat
# hence we will drop that rows

# %%
drop_match= df[((df.runs == 'TDNB') | ( df.runs == 'DNB') )].index

# %% [markdown]
# #### get the index of the data where the TDNB or DNB is present and drop it

# %%
drop_match
# Out:
# Int64Index([7, 14, 21, 111, 112, 116, 124, 133, 236], dtype='int64')

# %%
df.drop(drop_match,inplace=True)

# %% [markdown]
# ### Check the shape and info of the data

# %%
df.shape
# Out:
# (239, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 247
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    239 non-null    object
#  1   NotOut  239 non-null    int64
#  2   mins    239 non-null    object
#  3   bf      239 non-null    object
#  4   fours   239 non-null    object
#  5   sixes   239 non-null    object
#  6   sr      239 non-null    object
#  7   Inns    239 non-null    object
#  8   Opp     239 non-null    object
#  9   Ground  239 non-null    object
#  10  Date    239 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 22.4+ KB

# %% [markdown]
# ### here we will replace '-' with np.nan because we don't have information about that

# %%
df=df.replace('-',np.nan)

# %%
df.isnull().sum()
# Out:
# runs       0
# NotOut     0
# mins      33
# bf         0
# fours      0
# sixes      0
# sr         1
# Inns       0
# Opp        0
# Ground     0
# Date       0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# runs       0.000000
# NotOut     0.000000
# mins      13.807531
# bf         0.000000
# fours      0.000000
# sixes      0.000000
# sr         0.418410
# Inns       0.000000
# Opp        0.000000
# Ground     0.000000
# Date       0.000000
# dtype: float64

# %% [markdown]
# ### here mins contain more than 10% null values so we will drop that column

# %%
df1=df.drop(columns=['mins'])

# %%
df1
# Out:
#     runs  NotOut   bf fours sixes      sr Inns           Opp  \
# 0     12       0   22     1     0   54.54    1     Sri Lanka
# 1     37       0   67     6     0   55.22    2     Sri Lanka
# 2     25       0   38     4     0   65.78    1     Sri Lanka
# 3     54       0   66     7     0   81.81    1     Sri Lanka
# 4     31       0   46     3     1   67.39    2     Sri Lanka
# 5      2       1    2     0     0  100.00    1     Sri Lanka
# 6     16       0   24     1     0   66.66    2      Pakistan
# 8     79       1  104     9     2   75.96    2   West Indies
# 9     30       0   41     3     0   73.17    2     Australia
# 10    10       0   16     1     0   62.50    2     Australia
# 11    27       0   19     4     0  142.10    1     Sri Lanka
# 12    54       0   65     7     0   83.07    1     Sri Lanka
# 13   107       0  114    11     1   93.85    2     Sri Lanka
# 15     9       0   12     1     0   75.00    1     Sri Lanka
# ...

# %%
df1.isnull().sum()
# Out:
# runs      0
# NotOut    0
# bf        0
# fours     0
# sixes     0
# sr        1
# Inns      0
# Opp       0
# Ground    0
# Date      0
# dtype: int64

# %% [markdown]
# ### sr column contains one null value so we will fill it or drop that row

# %%
df1.replace(np.nan,0,inplace=True)

# %%
df1.isnull().sum()
# Out:
# runs      0
# NotOut    0
# bf        0
# fours     0
# sixes     0
# sr        0
# Inns      0
# Opp       0
# Ground    0
# Date      0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 247
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    239 non-null    object
#  1   NotOut  239 non-null    int64
#  2   bf      239 non-null    object
#  3   fours   239 non-null    object
#  4   sixes   239 non-null    object
#  5   sr      239 non-null    object
#  6   Inns    239 non-null    object
#  7   Opp     239 non-null    object
#  8   Ground  239 non-null    object
#  9   Date    239 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 20.5+ KB

# %% [markdown]
# ### here we will change the datatype from object to float and int

# %%
lst=['runs','bf','fours','sixes','Inns']

# %%
lst
# Out:
# ['runs', 'bf', 'fours', 'sixes', 'Inns']

# %%
for i in lst:
    df1[i]=df1[i].astype(str).astype(int)

df1['sr']=df1['sr'].astype(str).astype(float)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 247
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    239 non-null    int32
#  1   NotOut  239 non-null    int64
#  2   bf      239 non-null    int32
#  3   fours   239 non-null    int32
#  4   sixes   239 non-null    int32
#  5   sr      239 non-null    float64
#  6   Inns    239 non-null    int32
#  7   Opp     239 non-null    object
#  8   Ground  239 non-null    object
#  9   Date    239 non-null    object
# dtypes: float64(1), int32(5), int64(1), object(3)
# memory usage: 15.9+ KB

# %% [markdown]
# ### here we will drop few columns which are not necessary

# %%
df1.drop(columns=['Ground','Date'],inplace=True)

# %%
df1
# Out:
#      runs  NotOut   bf  fours  sixes      sr  Inns           Opp
# 0      12       0   22      1      0   54.54     1     Sri Lanka
# 1      37       0   67      6      0   55.22     2     Sri Lanka
# 2      25       0   38      4      0   65.78     1     Sri Lanka
# 3      54       0   66      7      0   81.81     1     Sri Lanka
# 4      31       0   46      3      1   67.39     2     Sri Lanka
# 5       2       1    2      0      0  100.00     1     Sri Lanka
# 6      16       0   24      1      0   66.66     2      Pakistan
# 8      79       1  104      9      2   75.96     2   West Indies
# 9      30       0   41      3      0   73.17     2     Australia
# 10     10       0   16      1      0   62.50     2     Australia
# 11     27       0   19      4      0  142.10     1     Sri Lanka
# 12     54       0   65      7      0   83.07     1     Sri Lanka
# 13    107       0  114     11      1   93.85     2     Sri Lanka
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 247
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   runs    239 non-null    int32
#  1   NotOut  239 non-null    int64
#  2   bf      239 non-null    int32
#  3   fours   239 non-null    int32
#  4   sixes   239 non-null    int32
#  5   sr      239 non-null    float64
#  6   Inns    239 non-null    int32
#  7   Opp     239 non-null    object
# dtypes: float64(1), int32(5), int64(1), object(1)
# memory usage: 12.1+ KB

# %% [markdown]
# ### Split the data into X and Y

# %%
X=df1.drop(columns=['runs'])
y=df1['runs']

# %%
X
# Out:
#      NotOut   bf  fours  sixes      sr  Inns           Opp
# 0         0   22      1      0   54.54     1     Sri Lanka
# 1         0   67      6      0   55.22     2     Sri Lanka
# 2         0   38      4      0   65.78     1     Sri Lanka
# 3         0   66      7      0   81.81     1     Sri Lanka
# 4         0   46      3      1   67.39     2     Sri Lanka
# 5         1    2      0      0  100.00     1     Sri Lanka
# 6         0   24      1      0   66.66     2      Pakistan
# 8         1  104      9      2   75.96     2   West Indies
# 9         0   41      3      0   73.17     2     Australia
# 10        0   16      1      0   62.50     2     Australia
# 11        0   19      4      0  142.10     1     Sri Lanka
# 12        0   65      7      0   83.07     1     Sri Lanka
# 13        0  114     11      1   93.85     2     Sri Lanka
# 15        0   12      1      0   75.00     1     Sri Lanka
# 16        0  102      7      0   89.21     2    Bangladesh
# ...

# %% [markdown]
# ### transform the categorical data into numerical data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [-1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[ 0.  ,  0.  ,  0.  , ...,  0.  , 54.54,  1.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  0.  , 55.22,  2.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  0.  , 65.78,  1.  ],
#        ...,
#        [ 0.  ,  0.  ,  0.  , ...,  0.  , 80.95,  1.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  0.  , 60.  ,  2.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  1.  , 75.  ,  1.  ]])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y
# Out:
# array([ 12,  36,  24,  48,  30,   2,  16,  68,  29,  10,  26,  48,  86,
#          9,  76,  62,  82,   2,  30,  50,   0,  71,  17,  61,  11,  17,
#         10,  27,   0,   8,  36,  96,  84,  57,  56,   0,   2,  48,  21,
#         27,  74,   2,  81,   8,  33,  12,   1,  52,  23,   9,  34,   2,
#         70,   0,  21,  78,  49,   9,   7,  16,  86,  36,  90,  34,  73,
#          0,   3,  95,  19,  22,  69,  30,  66,  17,  15,  12,  59,  20,
#        105,  87,  59, 113,  85,   1,  37, 102,  22,   0,   6,   7,  15,
#         36,  66,  25,   0,  30,  21,  21,  51,  40,  11,   2,  82,  30,
#          2,  93,  14,  61,  54,  81,  61,  93,   0,  73,  80,  18,  30,
#          0, 100,  67,   6,   2,  71, 106,  44,   5,   0,  39,   1,  13,
#          2,  55, 101,  21,  45,  47,  59, 108,   9,   4,   3,   8,  86,
#         43,  32,  32,  41,  37,   3,   1,   1,  22,  24,  11,  12,  66,
#        107,   7,  76,  52,  95,  85,   8,  72,   9, 110,  42,  58,  99,
# ...

# %% [markdown]
# ## Train Test and Split the Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train
# Out:
# array([[ 0.  ,  0.  ,  0.  , ...,  0.  , 54.54,  1.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  1.  , 75.24,  2.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 64.28,  2.  ],
#        ...,
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 33.33,  1.  ],
#        [ 0.  ,  1.  ,  0.  , ...,  0.  , 97.8 ,  2.  ],
#        [ 0.  ,  0.  ,  0.  , ...,  1.  , 77.14,  2.  ]])

# %% [markdown]
# ## Train the Model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor1 = DecisionTreeRegressor(random_state = 0)
regressor1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Check the Model accuracy

# %%
regressor1.score(X_test,y_test)
# Out:
# 0.9738575391493526

# %% [markdown]
# further changes will be done here

# %% [markdown]
# # Thank you...
